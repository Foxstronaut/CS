// %% [markdown]
// # APCS Array Lab 1
//
// 1. Which of the following choices is the correct syntax for declaring/initializing an array of integers?
//
//     ~~a.~~ ```int a[10];```
//
//     ~~b.~~ ```int[10] a = new int[10];```
//
//     ~~c.~~ ```[]int a = [10]int;```
//
//     **d.** ```int[] a = new int[10];```
//
//     ~~e.~~ ```int a[10] = new int[10];```
//
//    - the **int-based array** called **a** is defined as **this new int-based array**, **this new int-based array** has **10** empty spaces for data (in this case, **ints**)
//
// ---
//
// 2. Which of the following choices is the correct syntax for quickly declaring/initializing an array of integers to store a particular list of values?
//
//     a. `int[] a = {17, -3, 42, 5, 9, 28};`
//
//     ~~b.~~ `int a {17, -3, 42, 5, 9, 28};`
//
//     ~~c.~~ `int[] a = new int[6] {17, -3, 42, 5, 9, 28};`
//
//     ~~d.~~ `int[6] a = {17, -3, 42, 5, 9, 28};`
//
//     ~~e.~~ `int[] a = new {17, -3, 42, 5, 9, 28} [6];`
//
//    - **int based array called a** (creates new if non-existant) shall hold the data *"data defined in code"*
//    - length of var not req and makes syntax error, length is instead defined by number of comma seperated vars in the *"data defined in code"*
//
// ---
//
// 3. Fill in the array with the values that would be stored after the code executes:

// %%
import java.util.Arrays;

//snippet start

int[] data = new int[8];
data[0] = 3;
data[7] = -18;
data[4] = 5;
data[1] = data[0];

int x = data[4];
data[4] = 6;
data[x] = data[0] * data[1];

//snippet end
// Out:
// 9

// %% [markdown]
// |index|0|1|2|3|4|5|6|7|
// |:-|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
// |value after|3|3|0|0|6|9|0|-18|
//
// Now to check it:

// %%
System.out.println(Arrays.toString(data));
// Out:
// [3, 3, 0, 0, 6, 9, 0, -18]

// %% [markdown]
// Correct :)

// %%
int[] list = {2, 18, 6, -4, 5, 1};
for (int i = 0; i < list.length; i++) {
    list[i] = list[i] + (list[i] / list[0]);
}

// %% [markdown]
// |index|0|1|2|3|4|5|
// |:-|:-:|:-:|:-:|:-:|:-:|:-:|
// |value after|3|24|8|-5|6|1|
//
// Now to check it:

// %%
System.out.println(Arrays.toString(list));
// Out:
// [3, 24, 8, -5, 6, 1]

// %% [markdown]
// Correct :)
//
// 5. Complete the code:

// %% [markdown]
// ### oof, many errors

// %%
import java.util.Scanner;

public class PromptNumbers {
    public static void main(String[] args) {
        Scanner console = new Scanner(System.in);
        System.out.print("How many numbers will you enter? ");
        int count = console.nextInt();

        int[] ctnr = new int[count];

        for (int i = 0; i < count; i++) {
            System.out.print("Type a number: ");
            ctnr[i] = console.nextInt();
        }

        System.out.println();
        System.out.println("Your numbers in forward order:");
        for (int i = 0; i < count; i++) {
            System.out.println(ctnr[i]);
        }

        System.out.println();
        System.out.println("Your numbers in backward order:");
        for (int i = 0; i < count; i++) {
            System.out.println(ctnr[count - 1 - i]);
        }
    }
}

// %% [markdown]
// Now to test:
//
// (remove class and method defs for notebook software)

// %%
import java.util.Scanner;

Scanner console = new Scanner(System.in);
System.out.print("How many numbers will you enter? ");
int count = console.nextInt();

int[] ctnr = new int[count];

for (int i = 0; i < count; i++) {
    System.out.print("Type a number: ");
    ctnr[i] = console.nextInt();
}

System.out.println();
System.out.println("Your numbers in forward order:");
for (int i = 0; i < count; i++) {
    System.out.println(ctnr[i]);
}

System.out.println();
System.out.println("Your numbers in backward order:");
for (int i = 0; i < count; i++) {
    System.out.println(ctnr[count - 1 - i]);
}
// Out:
// How many numbers will you enter?
//  4
// Type a number:
//  5
// Type a number:
//  7
// Type a number:
//  6
// Type a number:
//  9
// Your numbers in forward order:
// 5
// 7
// 6
// 9
//
// Your numbers in backward order:
// 9
// 6
// 7
// 5
